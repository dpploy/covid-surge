# %% [markdown]
# [COVID-surge](https://github.com/dpploy/covid-surge) [https://github.com/dpploy/covid-surge] : V. F. de Almeida **14May20**
#
# ## US States Counties COVID-19 Surge Period Analysis
#
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
# $

# %% [markdown]
# ---
# ### Table of Contents<a id="toc"></a>
#  - [1) Introduction.](#intro)
#  - [2) Find states with fully evolved surges](#data)
#  - [3) Loop over: configure run, fit model to data, analysis.](#loop)
# ---

# %% [markdown]
# ## [Introduction](#toc)<a id="intro"></a>
#
# On-line COVID-19 data is used in this notebook, and a fit to the sigmoid function
#
# \begin{equation*}
# \boxed{ f(t) = \frac{\alpha_0}{1 + \alpha_1\, e^{\alpha_2\,t} } }
# \end{equation*}
#
# is systematically made. The time between points where the function has maximum and minimum curvature is computed and reported as the **surge period**. This period is relevant to public health officials to decide how long measures to control the epidemic should be in place. In addition, the surge period provides insight in comparing how different communities react to the epidemic.

# %%
'''Load the covid-surge package'''
#!pip install --upgrade --quiet covid-surge

from covid_surge import Surge
# %matplotlib inline

# %% [markdown]
# ## [Import Data](#toc)<a id="data"></a>

# %%
'''Import data'''

# Get complete US surge data
us_surge = Surge()

print('# of states/districts: ',len(us_surge.names))
print('# of days:             ',us_surge.dates.shape[0])
# Out:
# # of states/districts:  56
# # of days:              117

# %%
'''Set parameters'''

us_surge.end_date = '4/20/20'   # set end date wanted
us_surge.end_date = None        # get all the data available
us_surge.ignore_last_n_days = 2 # allow for data repo to be corrected/updated
us_surge.min_n_cases_abs = 500  # min # of absolute cases for analysis
us_surge.deaths_100k_minimum = 41 # US death per 100,000 for Chronic Lower Respiratory Diseases per year: 41 (2019)

# %%
'''Fit data to model function'''

# Fit data to all states
fit_data = us_surge.multi_fit_data()

states = list()

print('')
for (i,(sort_key,data)) in enumerate(fit_data):
    name = data[0]
    states.append(name)
    print('%2i) %15s: surge period %1.2f [day]'%(i,name,sort_key))
# Out:
#  0)        Virginia: surge period 17.57 [day]
#  1)        New York: surge period 18.56 [day]
#  2)     Connecticut: surge period 19.60 [day]
#  3)   Massachusetts: surge period 20.01 [day]
#  4)        Michigan: surge period 21.15 [day]
#  5)        Maryland: surge period 22.25 [day]
#  6)      New Jersey: surge period 22.33 [day]
#  7)       Minnesota: surge period 22.36 [day]
#  8)       Louisiana: surge period 22.90 [day]
#  9)        Colorado: surge period 23.11 [day]
# 10)    Pennsylvania: surge period 23.46 [day]
# 11)  North Carolina: surge period 23.51 [day]
# 12)         Indiana: surge period 24.80 [day]
# 13)         Georgia: surge period 25.18 [day]
# 14)         Florida: surge period 25.39 [day]
# 15)            Ohio: surge period 25.64 [day]
# 16)      California: surge period 25.64 [day]
# 17)        Illinois: surge period 26.90 [day]
# 18)        Missouri: surge period 27.20 [day]
# 19)      Washington: surge period 27.77 [day]

# %% [markdown]
# ## [Loop over: Configure Run, Fit Model to Data, Analysis.](#toc)<a id="loop"></a>

# %%
'''Loop over the top states and calculate the surge period for counties/towns'''

for state in states:

    print('')
    print('***************************************************************')
    print('                          ',state                               )
    print('***************************************************************')

    c_surge = Surge(locale='US',sub_locale=state)
    print('# of counties: ',len(c_surge.names))
    # Set parameters
    c_surge.end_date = '4/20/20'   # set end date wanted
    c_surge.end_date = None        # get all the data available
    c_surge.ignore_last_n_days = 2 # allow for data repo to be corrected/updated
    c_surge.min_n_cases_abs = 200  # min # of absolute cases for analysis
    c_surge.deaths_100k_minimum = 41 # US death per 100,000 for Chronic Lower Respiratory Diseases per year: 41 (2019)

    # Fit data to all counties/cities
    fit_data = c_surge.multi_fit_data()
    
    print('# of fittings done = ',len(fit_data))

    if len(fit_data) == 0:
        continue

    print('')
    for (sort_key,data) in fit_data:
        name = data[0]
        print('%15s: surge period %1.2f [day]'%(name,sort_key))

    # Create clustering bins based on surge period
    bins = c_surge.clustering(fit_data,2,'surge_period')

    print('')
    print('----------------------------------------------------------------')
    print('                            Bins                                ')
    print('----------------------------------------------------------------')
    for k in sorted(bins.keys()):
        print(' Bin %i %s'%(k,bins[k]))

    # Use bins to create groups of counties/cities based on surge period
    county_groups = dict()

    for (sort_key,data) in fit_data:
        county = data[0]
        param_vec = data[3]
        key = c_surge.get_bin_id(sort_key,bins)
        if key in county_groups:
            county_groups[key].append(county)
        else:
            county_groups[key] = list()
            county_groups[key].append(county)
                
    county_groups = [ county_groups[k] for k in
                         sorted(county_groups.keys(),reverse=False) ]

    print('')
    print('----------------------------------------------------------------')
    print('                        County Groups                           ')
    print('----------------------------------------------------------------')
    for g in county_groups:
        print(' Group %i %s'%(county_groups.index(g),g))

    # Plot the surge period for all grouped counties
    c_surge.plot_group_surge_periods( fit_data, bins )

    print('')
    print('')
# Out:
# ***************************************************************
#                            Virginia
# ***************************************************************
# # of counties:  133
# # of fittings done =  1
#
#         Fairfax: surge period 17.34 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [17.0, 18.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Fairfax']
# ***************************************************************
#                            New York
# ***************************************************************
# # of counties:  62
# # of fittings done =  7
#
#          Nassau: surge period 16.39 [day]
#        Rockland: surge period 17.24 [day]
#        New York: surge period 17.51 [day]
#     Westchester: surge period 17.87 [day]
#          Orange: surge period 20.93 [day]
#            Erie: surge period 23.64 [day]
#         Suffolk: surge period 23.78 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [16.0, 18.0]
#  Bin 1 [18.0, 20.0]
#  Bin 2 [20.0, 22.0]
#  Bin 3 [22.0, 24.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Nassau', 'Rockland', 'New York', 'Westchester']
#  Group 1 ['Orange']
#  Group 2 ['Erie', 'Suffolk']
# ***************************************************************
#                            Connecticut
# ***************************************************************
# # of counties:  8
# # of fittings done =  3
#
#        Hartford: surge period 17.42 [day]
#       Fairfield: surge period 20.16 [day]
#       New Haven: surge period 20.27 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [17.0, 19.0]
#  Bin 1 [19.0, 21.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Hartford']
#  Group 1 ['Fairfield', 'New Haven']
# ***************************************************************
#                            Massachusetts
# ***************************************************************
# # of counties:  14
# # of fittings done =  7
#
#         Norfolk: surge period 17.06 [day]
#         Suffolk: surge period 17.49 [day]
#       Middlesex: surge period 18.58 [day]
#         Hampden: surge period 18.63 [day]
#        Plymouth: surge period 18.99 [day]
#           Essex: surge period 21.87 [day]
#         Bristol: surge period 22.95 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [17.0, 19.0]
#  Bin 1 [19.0, 21.0]
#  Bin 2 [21.0, 23.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Norfolk', 'Suffolk', 'Middlesex', 'Hampden', 'Plymouth']
#  Group 1 ['Essex', 'Bristol']
# ***************************************************************
#                            Michigan
# ***************************************************************
# # of counties:  83
# # of fittings done =  4
#
#          Macomb: surge period 18.69 [day]
#         Genesee: surge period 18.87 [day]
#           Wayne: surge period 20.52 [day]
#         Oakland: surge period 23.66 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [18.0, 20.0]
#  Bin 1 [20.0, 22.0]
#  Bin 2 [22.0, 24.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Macomb', 'Genesee']
#  Group 1 ['Wayne']
#  Group 2 ['Oakland']
# ***************************************************************
#                            Maryland
# ***************************************************************
# # of counties:  24
# # of fittings done =  3
#
#      Montgomery: surge period 19.99 [day]
# Prince George's: surge period 22.35 [day]
#       Baltimore: surge period 23.80 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [19.0, 21.5]
#  Bin 1 [21.5, 24.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Montgomery']
#  Group 1 ["Prince George's", 'Baltimore']
# ***************************************************************
#                            New Jersey
# ***************************************************************
# # of counties:  21
# # of fittings done =  13
#
#          Hudson: surge period 16.92 [day]
#         Passaic: surge period 19.88 [day]
#        Somerset: surge period 19.96 [day]
#           Essex: surge period 20.54 [day]
#           Union: surge period 20.63 [day]
#          Bergen: surge period 21.51 [day]
#          Morris: surge period 22.09 [day]
#          Mercer: surge period 22.48 [day]
#      Burlington: surge period 23.38 [day]
#        Monmouth: surge period 23.38 [day]
#          Camden: surge period 25.11 [day]
#       Middlesex: surge period 26.25 [day]
#           Ocean: surge period 26.62 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [16.0, 18.2]
#  Bin 1 [18.2, 20.4]
#  Bin 2 [20.4, 22.6]
#  Bin 3 [22.6, 24.8]
#  Bin 4 [24.8, 27.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Hudson']
#  Group 1 ['Passaic', 'Somerset']
#  Group 2 ['Essex', 'Union', 'Bergen', 'Morris', 'Mercer']
#  Group 3 ['Burlington', 'Monmouth']
#  Group 4 ['Camden', 'Middlesex', 'Ocean']
# ***************************************************************
#                            Minnesota
# ***************************************************************
# # of counties:  87
# # of fittings done =  1
#
#        Hennepin: surge period 19.84 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [19.0, 20.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Hennepin']
# ***************************************************************
#                            Louisiana
# ***************************************************************
# # of counties:  64
# # of fittings done =  3
#
#       Jefferson: surge period 19.77 [day]
#         Orleans: surge period 22.10 [day]
# East Baton Rouge: surge period 24.55 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [19.0, 21.0]
#  Bin 1 [21.0, 23.0]
#  Bin 2 [23.0, 25.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Jefferson']
#  Group 1 ['Orleans']
#  Group 2 ['East Baton Rouge']
# ***************************************************************
#                            Colorado
# ***************************************************************
# # of counties:  64
# # of fittings done =  2
#
#        Arapahoe: surge period 18.84 [day]
#          Denver: surge period 22.75 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [18.0, 20.5]
#  Bin 1 [20.5, 23.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Arapahoe']
#  Group 1 ['Denver']
# ***************************************************************
#                            Pennsylvania
# ***************************************************************
# # of counties:  67
# # of fittings done =  6
#
#       Lancaster: surge period 17.63 [day]
#      Montgomery: surge period 21.50 [day]
#         Chester: surge period 21.84 [day]
#           Berks: surge period 22.31 [day]
#           Bucks: surge period 22.36 [day]
#    Philadelphia: surge period 25.03 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [17.0, 19.25]
#  Bin 1 [19.25, 21.5]
#  Bin 2 [21.5, 23.75]
#  Bin 3 [23.75, 26.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Lancaster']
#  Group 1 ['Montgomery']
#  Group 2 ['Chester', 'Berks', 'Bucks']
#  Group 3 ['Philadelphia']
# ***************************************************************
#                            North Carolina
# ***************************************************************
# # of counties:  100
# # of fittings done =  0
#
# ***************************************************************
#                            Indiana
# ***************************************************************
# # of counties:  92
# # of fittings done =  1
#
#          Marion: surge period 23.48 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [23.0, 24.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Marion']
# ***************************************************************
#                            Georgia
# ***************************************************************
# # of counties:  159
# # of fittings done =  0
#
# ***************************************************************
#                            Florida
# ***************************************************************
# # of counties:  67
# # of fittings done =  3
#
#      Miami-Dade: surge period 23.15 [day]
#         Broward: surge period 25.07 [day]
#      Palm Beach: surge period 27.18 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [23.0, 25.5]
#  Bin 1 [25.5, 28.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Miami-Dade', 'Broward']
#  Group 1 ['Palm Beach']
# ***************************************************************
#                            Ohio
# ***************************************************************
# # of counties:  88
# # of fittings done =  1
#
#           Lucas: surge period 21.10 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [21.0, 22.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Lucas']
# ***************************************************************
#                            California
# ***************************************************************
# # of counties:  58
# # of fittings done =  3
#
#     Los Angeles: surge period 23.12 [day]
#       Riverside: surge period 25.16 [day]
#       San Diego: surge period 27.15 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [23.0, 25.5]
#  Bin 1 [25.5, 28.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Los Angeles', 'Riverside']
#  Group 1 ['San Diego']
# ***************************************************************
#                            Illinois
# ***************************************************************
# # of counties:  102
# # of fittings done =  3
#
#            Lake: surge period 23.47 [day]
#            Will: surge period 24.30 [day]
#            Cook: surge period 26.64 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [23.0, 25.0]
#  Bin 1 [25.0, 27.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['Lake', 'Will']
#  Group 1 ['Cook']
# ***************************************************************
#                            Missouri
# ***************************************************************
# # of counties:  115
# # of fittings done =  0
#
# ***************************************************************
#                            Washington
# ***************************************************************
# # of counties:  39
# # of fittings done =  1
#
#            King: surge period 30.87 [day]
#
# ----------------------------------------------------------------
#                             Bins
# ----------------------------------------------------------------
#  Bin 0 [30.0, 31.0]
#
# ----------------------------------------------------------------
#                         County Groups
# ----------------------------------------------------------------
#  Group 0 ['King']
